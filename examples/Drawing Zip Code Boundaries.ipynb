# %% [markdown]
# ## Drawing ZIP Code Boundaries

# %% [markdown]
# This notebook recreates the choropleth from the article ["Drawing ZIP Code Boundaries"][1].
#
# [1]: http://www.christianpeccei.com/zipmap/

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
